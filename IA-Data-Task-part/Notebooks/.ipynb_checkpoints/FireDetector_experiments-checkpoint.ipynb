# %%
import sys
import os
import json
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
sys.path.append(os.path.abspath(".."))
from aiBrain.FireDetector import FireDetector
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       3 import pandas as pd
#       4 from datetime import datetime
# ----> 5 sys.path.append(os.path.abspath(".."))
#       6 from aiBrain.FireDetector import FireDetector
#       7 import sys
#
# NameError: name 'sys' is not defined

# %%
with open("/mnt/c/Users/ziade/OneDrive/Desktop/IgnisCore.io/IA-Data-Task-part/data/simulated_fire_random.json") as f:
    data = json.load(f)

detector = FireDetector()
preprocessed = detector.preprocess(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 with open("/mnt/c/Users/ziade/OneDrive/Desktop/IgnisCore.io/IA-Data-Task-part/data/simulated_fire_random.json") as f:
# ----> 2     data = json.load(f)
#       4 detector = FireDetector()
#       5 preprocessed = detector.preprocess(data)
#
# NameError: name 'json' is not defined

# %%
scores = detector.calculate_fire_risk(preprocessed)
action = detector.detect_fire(scores)
detector.log_result(scores, action)

# %%
df = pd.DataFrame([scores])
df.plot(kind='bar', y=['temp','smoke','ir','global'], title="Fire Risk Scores")
plt.ylabel("Score")
plt.xlabel("Metrics")
plt.ylim(0, 1)
plt.show()
