# %%
import sys
import os
import json
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
sys.path.append(os.path.abspath(".."))
from aiBrain.FireDetector import FireDetector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 8
#       6 from datetime import datetime
#       7 sys.path.append(os.path.abspath(".."))
# ----> 8 from aiBrain.FireDetector import FireDetector
#
# ModuleNotFoundError: No module named 'aiBrain'

# %%
with open("../data/simulated_fire.json") as f: 
    data = json.load(f) 

detector = FireDetector() 
preprocessed = detector.preprocess(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 with open("../data/simulated_fire.json") as f:
#       2     data = json.load(f)
#       4 detector = FireDetector()
#
# File ~/venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/simulated_fire.json'

# %%
scores = detector.calculate_fire_risk(preprocessed) 
action = detector.detect_fire(scores) 
detector.log_result(scores, action)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 scores = detector.calculate_fire_risk(preprocessed)
#       2 action = detector.detect_fire(scores)
#       3 detector.log_result(scores, action)
#
# NameError: name 'detector' is not defined

# %%
df = pd.DataFrame([scores])
df.plot(kind='bar', y=['temp','smoke','ir','global'], title="Fire Risk Scores")
plt.ylabel("Score")
plt.xlabel("Metrics")
plt.ylim(0, 1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df = pd.DataFrame([scores])
#       2 df.plot(kind='bar', y=['temp','smoke','ir','global'], title="Fire Risk Scores")
#       3 plt.ylabel("Score")
#
# NameError: name 'scores' is not defined
